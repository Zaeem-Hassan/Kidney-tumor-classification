# %%
print("hello")
# Out:
# hello

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1vlhZ5c7abUKF8xXERIw6m9Te8fW7ohw3&confirm=t&uuid=b971d28e-32fa-469e-936e-ae020799ec13
# To: e:\Kidney-tumor-classification\research\kidney-CT-Scan-data.zip
# 100%|██████████| 57.7M/57.7M [01:49<00:00, 527kB/s]
# 'kidney-CT-Scan-data.zip'
